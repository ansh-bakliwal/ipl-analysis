# %%
pip install pandas numpy matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\ansh\appdata\local\python\pythoncore-3.10-64\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\ansh\appdata\local\python\pythoncore-3.10-64\lib\site-packages (2.2.6)
# Requirement already satisfied: matplotlib in c:\users\ansh\appdata\local\python\pythoncore-3.10-64\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\ansh\appdata\local\python\pythoncore-3.10-64\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ansh\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ansh\appdata\local\python\pythoncore-3.10-64\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ansh\appdata\local\python\pythoncore-3.10-64\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\ansh\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ansh\appdata\local\python\pythoncore-3.10-64\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: pillow>=8 in c:\users\ansh\appdata\local\python\pythoncore-3.10-64\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ansh\appdata\local\python\pythoncore-3.10-64\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=3 in c:\users\ansh\appdata\local\python\pythoncore-3.10-64\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ansh\appdata\local\python\pythoncore-3.10-64\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ansh\appdata\local\python\pythoncore-3.10-64\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: six>=1.5 in c:\users\ansh\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

matches = pd.read_csv('../data/matches.csv')
deliveries = pd.read_csv('../data/deliveries.csv')

print("Matches shape:", matches.shape)
print("Deliveries shape:", deliveries.shape)
print("\nMatches columns:\n", matches.columns.tolist())
